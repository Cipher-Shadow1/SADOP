# %% [markdown]
# ## connection to the DB

# %%
import mysql.connector
import pandas as pd
import os

OUTPUT_DIR = r"A:\pc\Desktop\Code\data science\sadop\Data"
os.makedirs(OUTPUT_DIR, exist_ok=True)

conn = mysql.connector.connect(
    host="127.0.0.1",
    port=3307,
    user="sadop_user",
    password="1234",
    database="SADOP_BDD"
)
cursor = conn.cursor()
print("✅ Connected to SADOP_BDD")
# Out:
# ✅ Connected to SADOP_BDD

# %% [markdown]
# ## Extract each table → CSV

# %%
TABLES = {
    "user":         "users.csv",
    "accounts":     "accounts.csv",
    "transactions": "transactions.csv",
    "logs":         "logs.csv",
}

for table, filename in TABLES.items():
    print(f"⏳ Extracting {table} …", end=" ")
    df = pd.read_sql(f"SELECT * FROM {table}", conn)
    out = os.path.join(OUTPUT_DIR, filename)
    df.to_csv(out, index=False)
    print(f"✅ {len(df):,} rows  →  {out}")

print("\n🎉 All tables exported successfully!")
cursor.close()
conn.close()
# Out:
# ⏳ Extracting user …
# C:\Users\pc\AppData\Local\Temp\ipykernel_31076\3835806732.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM {table}", conn)
# ✅ 20,000 rows  →  A:\pc\Desktop\Code\data science\sadop\Data\users.csv
# ⏳ Extracting accounts … ✅ 35,000 rows  →  A:\pc\Desktop\Code\data science\sadop\Data\accounts.csv
# ⏳ Extracting transactions … ✅ 250,000 rows  →  A:\pc\Desktop\Code\data science\sadop\Data\transactions.csv
# ⏳ Extracting logs … ✅ 300,000 rows  →  A:\pc\Desktop\Code\data science\sadop\Data\logs.csv
#
# 🎉 All tables exported successfully!
